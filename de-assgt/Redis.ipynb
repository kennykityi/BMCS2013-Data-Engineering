# %% [markdown]
# ## Author: Kelly Tan Jie Li
# ---

# %%
import csv
import redis
from classes.redis_manager import RedisManager

# %%
input_csv = '/home/student/de-assgt/content/final_dictionary/final_dictionary.csv'
RedisManager.store_data_to_redis(input_csv)
RedisManager.clean_up(input_csv)
print(f"Content has been saved to Redis")
# Out:
# Content has been saved to Redis
